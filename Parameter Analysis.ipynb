# %%
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
dataset=pd.read_csv("real_2013.csv")
dataset
# Out:
#         T    TM    Tm     SLP   H   VV     V    VM      PM 2.5
# 0     7.4   9.8   4.8  1017.6  93  0.5   4.3   9.4  219.720833
# 1     7.8  12.7   4.4  1018.5  87  0.6   4.4  11.1  182.187500
# 2     6.7  13.4   2.4  1019.4  82  0.6   4.8  11.1  154.037500
# 3     8.6  15.5   3.3  1018.7  72  0.8   8.1  20.6  223.208333
# 4    12.4  20.9   4.4  1017.3  61  1.3   8.7  22.2  200.645833
# ..    ...   ...   ...     ...  ..  ...   ...   ...         ...
# 180  14.6  15.9  12.5  1016.9  95  0.5   0.4   3.5  288.416667
# 181  13.6  20.4   7.5  1020.7  67  1.1  10.2  40.7  166.916667
# 182  12.3  20.6   6.2  1019.4  71  1.3   4.4  18.3  169.000000
# 183  11.9  17.1   6.5  1018.6  84  1.1   1.1   5.4  186.041667
# 184  14.3  19.2  10.9  1020.5  91  1.6   4.8  11.1         NaN
#
# [185 rows x 9 columns]

# %%
dataset.isnull().values.any()
# Out:
# True

# %%
dataset=dataset.dropna()

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
temp=dataset.iloc[:,0:1].values;
temp
# Out:
# array([[ 7.4],
#        [ 7.8],
#        [ 6.7],
#        [ 8.6],
#        [12.4],
#        [16. ],
#        [13.4],
#        [14.3],
#        [12.7],
#        [11.9],
#        [12.2],
#        [13.4],
#        [12.3],
#        [13.7],
#        [14.9],
#        [15. ],
#        [16.3],
#        [18.7],
#        [14.6],
#        [14.7],
#        [14.8],
#        [17.4],
#        [18.1],
#        [18.3],
#        [16.4],
#        [16.9],
#        [19.3],
#        [17.2],
#        [17.7],
#        [20.4],
#        [18.2],
#        [19. ],
#        [18.7],
#        [22.6],
#        [22.5],
#        [24. ],
#        [23.8],
#        [22.6],
#        [23. ],
#        [24.6],
#        [27.1],
#        [26.1],
#        [23.6],
#        [23.2],
#        [23.8],
#        [24.7],
#        [25.6],
#        [25.7],
#        [25.1],
#        [29.5],
#        [29.2],
#        [31.1],
#        [29.8],
#        [28.2],
#        [28.3],
#        [29.3],
#        [30.5],
#        [28. ],
# ...

# %%
maxtemp=dataset.iloc[:,1:2].values
maxtemp
# Out:
# array([[ 9.8],
#        [12.7],
#        [13.4],
#        [15.5],
#        [20.9],
#        [25.2],
#        [21. ],
#        [22.6],
#        [18.9],
#        [18.9],
#        [19.9],
#        [21.1],
#        [21.4],
#        [22. ],
#        [21.9],
#        [24. ],
#        [24. ],
#        [26.3],
#        [21.6],
#        [21.7],
#        [22.6],
#        [25.4],
#        [26.7],
#        [23.2],
#        [22. ],
#        [23.5],
#        [26.9],
#        [24.2],
#        [26.5],
#        [28.4],
#        [26.1],
#        [26.8],
#        [27.8],
#        [30.6],
#        [31.8],
#        [33.8],
#        [33. ],
#        [33. ],
#        [30. ],
#        [31.7],
#        [34.8],
#        [34.8],
#        [34.3],
#        [29.6],
#        [30.9],
#        [31.5],
#        [33.8],
#        [36. ],
#        [36. ],
#        [37. ],
#        [37.5],
#        [37.8],
#        [36.6],
#        [36.6],
#        [36.4],
#        [37.9],
#        [38.6],
#        [38.6],
# ...

# %%
mintemp=dataset.iloc[:,2:3].values
mintemp
# Out:
# array([[ 4.8],
#        [ 4.4],
#        [ 2.4],
#        [ 3.3],
#        [ 4.4],
#        [10. ],
#        [ 9.2],
#        [ 6.6],
#        [ 7.3],
#        [ 6.3],
#        [ 6.2],
#        [ 5.6],
#        [ 6.4],
#        [ 7. ],
#        [ 7.1],
#        [ 7.6],
#        [12. ],
#        [ 9.5],
#        [ 9.4],
#        [ 8.4],
#        [ 8.5],
#        [10.3],
#        [10.2],
#        [12.7],
#        [11.2],
#        [10.1],
#        [12.1],
#        [10.8],
#        [ 9.8],
#        [15.2],
#        [12.2],
#        [11.7],
#        [13.3],
#        [15.7],
#        [13.7],
#        [13.6],
#        [14.9],
#        [18.1],
#        [14.4],
#        [17.9],
#        [17.7],
#        [17.9],
#        [17.7],
#        [16.7],
#        [16.7],
#        [17. ],
#        [17.9],
#        [17.8],
#        [18.3],
#        [18.5],
#        [20. ],
#        [21.7],
#        [21.4],
#        [21.9],
#        [20.1],
#        [20.3],
#        [20.7],
#        [23.8],
# ...

# %%
aqi=dataset.iloc[:,8:9].values
aqi
# Out:
# array([[219.72083333],
#        [182.1875    ],
#        [154.0375    ],
#        [223.20833333],
#        [200.64583333],
#        [285.225     ],
#        [236.825     ],
#        [276.90833333],
#        [108.        ],
#        [107.625     ],
#        [125.89166667],
#        [181.0125    ],
#        [152.55416667],
#        [152.32083333],
#        [319.7375    ],
#        [332.70833333],
#        [279.6       ],
#        [179.11666667],
#        [ 54.79166667],
#        [ 93.375     ],
#        [103.        ],
#        [132.20833333],
#        [127.70833333],
#        [109.33333333],
#        [ 56.45833333],
#        [135.83333333],
#        [122.5       ],
#        [ 69.66666667],
#        [ 79.83333333],
#        [ 62.70833333],
#        [ 21.20833333],
#        [  1.91666667],
#        [  1.83333333],
#        [105.83333333],
#        [117.58333333],
#        [122.70833333],
#        [111.95833333],
#        [ 59.20833333],
#        [ 77.20833333],
#        [ 98.70833333],
# ...

# %%
pressure=dataset.iloc[:,3:4].values
pressure
# Out:
# array([[1017.6],
#        [1018.5],
#        [1019.4],
#        [1018.7],
#        [1017.3],
#        [1013.2],
#        [1015.1],
#        [1016.3],
#        [1021.2],
#        [1020.1],
#        [1021. ],
#        [1020. ],
#        [1019.6],
#        [1018.2],
#        [1018.3],
#        [1017.4],
#        [1017.2],
#        [1015.3],
#        [1018.4],
#        [1017.1],
#        [1016.8],
#        [1015.8],
#        [1013.8],
#        [1011.2],
#        [1015.5],
#        [1016.8],
#        [1015.6],
#        [1018.3],
#        [1015.3],
#        [1014.7],
#        [1016.3],
#        [1016.3],
#        [1016.2],
#        [1015.4],
#        [1014.6],
#        [1009.7],
#        [1010.4],
#        [1013.1],
#        [1016.1],
#        [1008.5],
#        [1009.7],
#        [1008.8],
#        [1010.4],
#        [1008.6],
#        [1009. ],
#        [1008.6],
#        [1008.7],
#        [1009. ],
#        [1009.5],
#        [1005.2],
#        [1006.1],
#        [1005.6],
# ...

# %%
humidity=dataset.iloc[:,4:5].values
humidity
# Out:
# array([[93],
#        [87],
#        [82],
#        [72],
#        [61],
#        [79],
#        [87],
#        [76],
#        [76],
#        [76],
#        [69],
#        [60],
#        [70],
#        [63],
#        [73],
#        [81],
#        [80],
#        [64],
#        [72],
#        [71],
#        [67],
#        [63],
#        [61],
#        [75],
#        [81],
#        [80],
#        [74],
#        [74],
#        [73],
#        [62],
#        [54],
#        [58],
#        [69],
#        [62],
#        [57],
#        [53],
#        [64],
#        [67],
#        [55],
#        [68],
#        [52],
#        [54],
#        [51],
#        [54],
#        [52],
#        [57],
#        [47],
#        [50],
#        [56],
#        [30],
#        [38],
#        [34],
#        [37],
#        [45],
#        [47],
#        [35],
#        [36],
#        [48],
#        [45],
#        [53],
#        [38],
#        [24],
#        [29],
#        [35],
#        [36],
#        [29],
# ...

# %%
vvisibility=dataset.iloc[:,5:6].values
vvisibility
# Out:
# array([[0.5],
#        [0.6],
#        [0.6],
#        [0.8],
#        [1.3],
#        [0.6],
#        [0.5],
#        [0.8],
#        [1.8],
#        [1.1],
#        [2.1],
#        [1.9],
#        [1.9],
#        [1.8],
#        [0.6],
#        [0.6],
#        [0.8],
#        [1.6],
#        [2.7],
#        [1.8],
#        [2.1],
#        [1.9],
#        [2.6],
#        [1.9],
#        [1.6],
#        [1.3],
#        [1.6],
#        [2.6],
#        [1.4],
#        [2.4],
#        [1.9],
#        [2.6],
#        [2.4],
#        [2.6],
#        [2.3],
#        [1.9],
#        [1.9],
#        [2.1],
#        [2.7],
#        [2.3],
#        [1.6],
#        [2.6],
#        [2.6],
#        [1.9],
#        [1.6],
#        [2.1],
#        [2.1],
#        [1.8],
#        [2.7],
#        [1.9],
#        [2.6],
#        [1.8],
#        [1.9],
#        [1.9],
#        [1.9],
#        [2.3],
#        [1.9],
#        [2.3],
#        [1.9],
#        [1.9],
#        [2.3],
#        [1.9],
# ...

# %%
visibility=dataset.iloc[:,6:7].values
visibility
# Out:
# array([[ 4.3],
#        [ 4.4],
#        [ 4.8],
#        [ 8.1],
#        [ 8.7],
#        [ 4.8],
#        [ 1.5],
#        [ 0.4],
#        [ 6.1],
#        [ 8.3],
#        [ 4.4],
#        [ 8. ],
#        [ 6.7],
#        [ 7.2],
#        [ 2. ],
#        [ 2.2],
#        [ 1.3],
#        [ 1.7],
#        [ 9.4],
#        [10.9],
#        [ 9.3],
#        [ 6.7],
#        [ 5. ],
#        [10. ],
#        [ 5.9],
#        [ 5.2],
#        [ 5.9],
#        [ 4.6],
#        [ 4.8],
#        [ 5. ],
#        [24.4],
#        [16.7],
#        [ 7.4],
#        [ 8.1],
#        [ 5.9],
#        [ 4.6],
#        [ 3.9],
#        [11.3],
#        [ 6.7],
#        [14.1],
#        [ 6.1],
#        [11.9],
#        [15.9],
#        [13.1],
#        [ 6.5],
#        [ 7.6],
#        [ 4.4],
#        [ 9.3],
#        [ 9.1],
#        [10.6],
#        [ 5.9],
#        [ 8.1],
#        [ 8.1],
#        [ 6.5],
#        [ 6.3],
#        [ 4.4],
#        [ 7.6],
#        [15.6],
# ...

# %%
pl.scatter(temp,aqi,color="red")
pl.xlabel("Temperature")
pl.ylabel("PM 2.5")
pl.show()

# %%
pl.scatter(maxtemp,aqi,color="red")
pl.xlabel("Max Temperature")
pl.ylabel("PM 2.5")
pl.show()

# %%
pl.scatter(mintemp,aqi,color="red")
pl.xlabel("Min Temperature")
pl.ylabel("PM 2.5")
pl.show()

# %%
pl.scatter(pressure,aqi,color="red")
pl.xlabel("Sea Level Pressure")
pl.ylabel("PM 2.5")
pl.show()

# %%
pl.scatter(humidity,aqi,color="red")
pl.xlabel("Humidity")
pl.ylabel("PM 2.5")
pl.show()

# %%
pl.scatter(vvisibility,aqi,color="red")
pl.xlabel("Vertical Visibility")
pl.ylabel("PM 2.5")
pl.show()

# %%
pl.scatter(visibility,aqi,color="red")
pl.xlabel("Visibility")
pl.ylabel("PM 2.5")
pl.show()
